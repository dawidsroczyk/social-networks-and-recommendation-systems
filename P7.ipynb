# %%
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

# %% [markdown]
# ![alt text](7_4-5.jpg "Title")

# %% [markdown]
# ![alt text](7_6.jpg "Title")

# %%
N = 500
k_vals = np.linspace(0, 3, 30)
sizes = []

for k in k_vals:
    p = k/N
    G = nx.erdos_renyi_graph(N, p)
    comps = list(nx.connected_components(G))
    sizes.append(len(max(comps, key=len)) if comps else 0)

plt.plot(k_vals, np.array(sizes)/N)
plt.axvline(x=1, color='r', linestyle='--')
plt.xlabel('⟨k⟩')
plt.ylabel('omponent size / N')
plt.show()
